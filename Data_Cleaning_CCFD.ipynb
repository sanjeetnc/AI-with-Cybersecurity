# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjeetnc/AI-with-Cybersecurity/blob/main/Data_Cleaning_CCFD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
dp=files.upload()
# Out:
#      <input type="file" id="files-431c6e11-ee86-46e1-bfb3-8a763e6f420d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-431c6e11-ee86-46e1-bfb3-8a763e6f420d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r"Credit_Card_Fraud_Detection.xlsx")
data
# Out:
#      Unnamed: 0  Customer_ID  A_1    A_2     A_3  A_4  A_5  A_6    A_7  A_8  \
# 0             0     15776156    1  22.08  11.460    2    4    4  1.585    0
# 1             1     15739548    0  22.67   7.000    2    8    4  0.165    0
# 2             2     15662854    0  29.58   1.750    1    4    4  1.250    0
# 3             3     15687688    0  21.67  11.500    1    5    3  0.000    1
# 4             4     15715750    1  20.17   8.170    2    6    4  1.960    1
# ..          ...          ...  ...    ...     ...  ...  ...  ...    ...  ...
# 685         685     15808223    1  31.57  10.500    2   14    4  6.500    1
# 686         686     15769980    1  20.67   0.415    2    8    4  0.125    0
# 687         687     15675450    0  18.83   9.540    2    6    4  0.085    1
# 688         688     15776494    0  27.42  14.500    2   14    8  3.085    1
# 689         689     15592412    1  41.00   0.040    2   10    4  0.040    0
#
#      A_9  A_10  A_11  A_12  A_13  A_14  class
# ...

# %%
df=pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   690 non-null    int64
#  1   Customer_ID  690 non-null    int64
#  2   A_1          690 non-null    int64
#  3   A_2          690 non-null    float64
#  4   A_3          690 non-null    float64
#  5   A_4          690 non-null    int64
#  6   A_5          690 non-null    int64
#  7   A_6          690 non-null    int64
#  8   A_7          690 non-null    float64
#  9   A_8          690 non-null    int64
#  10  A_9          690 non-null    int64
#  11  A_10         690 non-null    int64
#  12  A_11         690 non-null    int64
#  13  A_12         690 non-null    int64
#  14  A_13         690 non-null    int64
#  15  A_14         690 non-null    int64
#  16  class        690 non-null    int64
# dtypes: float64(3), int64(14)
# memory usage: 91.8 KB

# %%
df.isnull()
# Out:
#      Unnamed: 0  Customer_ID    A_1    A_2    A_3    A_4    A_5    A_6    A_7  \
# 0         False        False  False  False  False  False  False  False  False
# 1         False        False  False  False  False  False  False  False  False
# 2         False        False  False  False  False  False  False  False  False
# 3         False        False  False  False  False  False  False  False  False
# 4         False        False  False  False  False  False  False  False  False
# ..          ...          ...    ...    ...    ...    ...    ...    ...    ...
# 685       False        False  False  False  False  False  False  False  False
# 686       False        False  False  False  False  False  False  False  False
# 687       False        False  False  False  False  False  False  False  False
# 688       False        False  False  False  False  False  False  False  False
# 689       False        False  False  False  False  False  False  False  False
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# Customer_ID    0
# A_1            0
# A_2            0
# A_3            0
# A_4            0
# A_5            0
# A_6            0
# A_7            0
# A_8            0
# A_9            0
# A_10           0
# A_11           0
# A_12           0
# A_13           0
# A_14           0
# class          0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0   Customer_ID         A_1         A_2         A_3  \
# count  690.000000  6.900000e+02  690.000000  690.000000  690.000000
# mean   344.500000  1.569047e+07    0.678261   31.568203    4.758725
# std    199.330128  7.150647e+04    0.467482   11.853273    4.978163
# min      0.000000  1.556571e+07    0.000000   13.750000    0.000000
# 25%    172.250000  1.563169e+07    0.000000   22.670000    1.000000
# 50%    344.500000  1.569016e+07    1.000000   28.625000    2.750000
# 75%    516.750000  1.575190e+07    1.000000   37.707500    7.207500
# max    689.000000  1.581544e+07    1.000000   80.250000   28.000000
#
#               A_4         A_5         A_6         A_7         A_8         A_9  \
# count  690.000000  690.000000  690.000000  690.000000  690.000000  690.000000
# mean     1.766667    7.372464    4.692754    2.223406    0.523188    0.427536
# std      0.430063    3.683265    1.992316    3.346513    0.499824    0.495080
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 685    False
# 686    False
# 687    False
# 688    False
# 689    False
# Length: 690, dtype: bool

# %%
df.drop_duplicates()
# Out:
#      Unnamed: 0  Customer_ID  A_1    A_2     A_3  A_4  A_5  A_6    A_7  A_8  \
# 0             0     15776156    1  22.08  11.460    2    4    4  1.585    0
# 1             1     15739548    0  22.67   7.000    2    8    4  0.165    0
# 2             2     15662854    0  29.58   1.750    1    4    4  1.250    0
# 3             3     15687688    0  21.67  11.500    1    5    3  0.000    1
# 4             4     15715750    1  20.17   8.170    2    6    4  1.960    1
# ..          ...          ...  ...    ...     ...  ...  ...  ...    ...  ...
# 685         685     15808223    1  31.57  10.500    2   14    4  6.500    1
# 686         686     15769980    1  20.67   0.415    2    8    4  0.125    0
# 687         687     15675450    0  18.83   9.540    2    6    4  0.085    1
# 688         688     15776494    0  27.42  14.500    2   14    8  3.085    1
# 689         689     15592412    1  41.00   0.040    2   10    4  0.040    0
#
#      A_9  A_10  A_11  A_12  A_13  A_14  class
# ...

# %%
df.dropna() #removes_blank_space
# Out:
#      Unnamed: 0  Customer_ID  A_1    A_2     A_3  A_4  A_5  A_6    A_7  A_8  \
# 0             0     15776156    1  22.08  11.460    2    4    4  1.585    0
# 1             1     15739548    0  22.67   7.000    2    8    4  0.165    0
# 2             2     15662854    0  29.58   1.750    1    4    4  1.250    0
# 3             3     15687688    0  21.67  11.500    1    5    3  0.000    1
# 4             4     15715750    1  20.17   8.170    2    6    4  1.960    1
# ..          ...          ...  ...    ...     ...  ...  ...  ...    ...  ...
# 685         685     15808223    1  31.57  10.500    2   14    4  6.500    1
# 686         686     15769980    1  20.67   0.415    2    8    4  0.125    0
# 687         687     15675450    0  18.83   9.540    2    6    4  0.085    1
# 688         688     15776494    0  27.42  14.500    2   14    8  3.085    1
# 689         689     15592412    1  41.00   0.040    2   10    4  0.040    0
#
#      A_9  A_10  A_11  A_12  A_13  A_14  class
# ...

# %%
df.fillna("No records") #fill blank with input string
# Out:
#      Unnamed: 0  Customer_ID  A_1    A_2     A_3  A_4  A_5  A_6    A_7  A_8  \
# 0             0     15776156    1  22.08  11.460    2    4    4  1.585    0
# 1             1     15739548    0  22.67   7.000    2    8    4  0.165    0
# 2             2     15662854    0  29.58   1.750    1    4    4  1.250    0
# 3             3     15687688    0  21.67  11.500    1    5    3  0.000    1
# 4             4     15715750    1  20.17   8.170    2    6    4  1.960    1
# ..          ...          ...  ...    ...     ...  ...  ...  ...    ...  ...
# 685         685     15808223    1  31.57  10.500    2   14    4  6.500    1
# 686         686     15769980    1  20.67   0.415    2    8    4  0.125    0
# 687         687     15675450    0  18.83   9.540    2    6    4  0.085    1
# 688         688     15776494    0  27.42  14.500    2   14    8  3.085    1
# 689         689     15592412    1  41.00   0.040    2   10    4  0.040    0
#
#      A_9  A_10  A_11  A_12  A_13  A_14  class
# ...

# %%
avg=df['A_1'].mean()
avg
# Out:
# np.float64(0.6782608695652174)

# %%
df.to_csv("Credit_Card_Fraud_Detection.csv")
files.download("Credit_Card_Fraud_Detection.csv")

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Customer_ID'],df['A_2'])

# %%
plt.scatter(df['A_3'],df['A_2'])
plt.title('Scatter Plot')
plt.xlabel('A_3')
plt.ylabel('A_2')
plt.show()

# %%
plt.bar(df['A_3'],df['A_2'])
plt.title('bar Plot')
plt.xlabel('A_3')
plt.ylabel('A_2')
plt.show()

# %%
plt.plot(df['A_1'],df['A_10'])
plt.title(' Plot')
plt.xlabel('trans_date_trans_time')
plt.ylabel('amt')
plt.show()

# %%
plt.hist(df['A_2'])
plt.title('hist Plot')
plt.xlabel('A_2')
plt.ylabel('A_4')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.suptitle("final report")
plt.subplot(2,2,1)
plt.scatter(df['Customer_ID'],df['A_7'])
plt.title('Scatter Plot')
plt.xlabel('Customer_ID')
plt.ylabel('A_7')



plt.subplot(2,2,2)
plt.pie(df['A_13'],df['A_8'])
plt.title('pie Plot')
plt.xlabel('Customer_ID')
plt.ylabel('A_7')
plt.subplot(2,2,3)
plt.plot(df['Customer_ID'],df['A_7'])
plt.title(' Plot')
plt.xlabel('Customer_ID')
plt.ylabel('A_7')



plt.subplot(2,2,4)
plt.hist(df['A_7'])
plt.title('hist Plot')
plt.xlabel('Customer_ID')
plt.ylabel('A_7')

plt.savefig("Credit_Card_Fraud_Detection.png")
plt.show()
# Out:
# /tmp/ipython-input-935750275.py:12: MatplotlibDeprecationWarning: Passing the explode parameter of pie() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.pie(df['A_13'],df['A_8'])

# %%
files.download("Credit_Card_Fraud_Detection.png")
